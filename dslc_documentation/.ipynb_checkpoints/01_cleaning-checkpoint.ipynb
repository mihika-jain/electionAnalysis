# %% [markdown]
# # Cleaning
#
# [DSLC stages]: Data cleaning and pre-processing
#
#
# Start by loading in any libraries that you will use in this document.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Domain problem formulation
#
# Write a summary of the problem.

# %% [markdown]
# ## Data source overview
#
# Briefly describe where the data being used for this project came from

# %% [markdown]
# ## Step 1: Review background information {#sec-bg-info}
#
# ### Information on data collection
#
# Write a summary of how the data was collected.
#
# ### Data dictionary
#
# If there is a data dictionary, give some details here.
#
#
# ### Answering questions about the background information
#
# Answer the recommended background information questions from the Data Cleaning chapter.
#
# - *What does each variable measure?*
#
# - *How was the data collected?*
#
# - *What are the observational units?*
#
# - *Is the data relevant to my project?*

# %% [markdown]
# ## Step 2: Loading in the data
#
#
# Load in the data.

# %%
data_orig = pd.read_csv(r"..\data\anes_timeseries_2020_csv_20220210.csv")
# Out:
# C:\Users\15184\AppData\Local\Temp\ipykernel_51260\1382818064.py:1: DtypeWarning: Columns (15,17,18,19,21,22,23,25,26,27,29,30,31,33,34,35,37,38,1508,1509) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_orig = pd.read_csv(r"..\data\anes_timeseries_2020_csv_20220210.csv")

# %% [markdown]
# Let's look at the first few rows to make sure it looks like it has been loaded in correctly:

# %%
data_orig.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'POST_ProblemMention'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 data_orig['POST_ProblemMention'].value_counts()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'POST_ProblemMention'

# %% [markdown]
# And let's examine the dimension of the data.

# %%
dictionary = {
  "V201033": {"column": "PRE_VotePresident", "unique_values": 5, "type": "cat"},
  "V201218": {"column": "PRE_RaceOutcomePrediction", "unique_values": 2, "type": "cat"},
  "V201151": {"column": "PRE_ThermoBiden", "unique_values": 100, "type": "rank"},
  "V201152": {"column": "PRE_ThermoTrump", "unique_values": 100, "type": "rank"},
  "V201153": {"column": "PRE_ThermoHarris", "unique_values": 100, "type": "rank"},
  "V201154": {"column": "PRE_ThermoPence", "unique_values": 100, "type": "rank"},
  "V201155": {"column": "PRE_ThermoObama", "unique_values": 100, "type": "rank"},
  "V201156": {"column": "PRE_ThermoDemParty", "unique_values": 100, "type": "rank"},
  "V201157": {"column": "PRE_ThermoRepParty", "unique_values": 100, "type": "rank"},
  "V201553": {"column": "PRE_ParentNativeStatus", "unique_values": 3, "type": "cat"},
  "V201587": {"column": "PRE_YearsAtAddress", "unique_values": 40, "type": "num"},
  "V201600": {"column": "Sex", "unique_values": 2, "type": "cat"},
  "V201225x": {"column": "PRE_SummaryVoteDutyChoice", "unique_values": 7, "type": "rank"},
  "V201231x": {"column": "PRE_PartyID", "unique_values": 7, "type": "rank"},
  "V201246": {"column": "PRE_ScaleSpendingServices", "unique_values": 7, "type": "rank"},
  #"V201018": {"column": "PRE_PartyRegistration", "unique_values": 4, "type": "cat"},
  "V201115": {"column": "PRE_CountryDirection", "unique_values": 5, "type": "rank"},
  "V201233": {"column": "PRE_GovTrust", "unique_values": 5, "type": "rank"},
  "V201324": {"column": "PRE_EconomyView", "unique_values": 5, "type": "rank"},
  "V201340": {"column": "PRE_AbortionRightsSC", "unique_values": 3, "type": "cat"},
  "V201507x": {"column": "Age", "unique_values": 80, "type": "num"},
  "V201510": {"column": "EducationLevel", "unique_values": 8, "type": "cat"},
  "V201517": {"column": "WorkStatus", "unique_values": 2, "type": "cat"},
  "V201617x": {"column": "Income", "unique_values": 22, "type": "rank"},
  "V201549x": {"column": "Race", "unique_values": 6, "type": "cat"},
  "V202054x": {"column": "StateRegistration", "unique_values": 56, "type": "cat"},
  "V201567": {"column": "HouseholdChildren", "unique_values": 5, "type": "rank"},
  "V201630b": {"column": "PRE_Fox_Hannity", "unique_values": 2, "type": "cat"},
  "V201630c": {"column": "PRE_Fox_TuckerCarlsonTonight", "unique_values": 2, "type": "cat"},
  "V201630k": {"column": "PRE_Fox_SpecialReportBretBaier", "unique_values": 2, "type": "cat"},
  "V201630f": {"column": "PRE_Fox_TheFive", "unique_values": 2, "type": "cat"},
  "V201630g": {"column": "PRE_Fox_TheIngrahamAngle", "unique_values": 2, "type": "cat"},
  "V201630h": {"column": "PRE_Fox_TheStoryMarthaMacCallum", "unique_values": 2, "type": "cat"},
  "V201631k": {"column": "PRE_Fox_FoxAndFriends", "unique_values": 2, "type": "cat"},
  "V201634f": {"column": "PRE_Fox_FoxNewsWebsite", "unique_values": 2, "type": "cat"},
  "V201630i": {"column": "PRE_CNN_TheLeadJakeTapper", "unique_values": 2, "type": "cat"},
  "V201630j": {"column": "PRE_CNN_AndersonCooper360", "unique_values": 2, "type": "cat"},
  "V201630q": {"column": "PRE_CNN_CuomoPrimeTime", "unique_values": 2, "type": "cat"},
  "V201631b": {"column": "PRE_CNN_ErinBurnettOutFront", "unique_values": 2, "type": "cat"},
  "V201634b": {"column": "PRE_CNN_CNNWebsite", "unique_values": 2, "type": "cat"},
  "V201630n": {"column": "PRE_ABC_WorldNewsTonight", "unique_values": 2, "type": "cat"},
  "V201631d": {"column": "PRE_ABC_2020", "unique_values": 2, "type": "cat"},
  "V201631i": {"column": "PRE_ABC_GoodMorningAmerica", "unique_values": 2, "type": "cat"},
  "V201646": {"column": "PRE_PartyMoreHouseMembers", "unique_values": 2, "type": "cat"},
  "V201645": {"column": "PRE_FederalSpendingKnowledge", "unique_values": 4, "type": "cat"},
  "V201351": {"column": "PRE_VoteAccuracy", "unique_values": 5, "type": "rank"},
  "V201650": {"column": "PRE_SurveySeriousness", "unique_values": 5, "type": "rank"},
  "V201249": {"column": "PRE_ScaleDefenseSpending", "unique_values": 7, "type": "rank"},
  "V201252": {"column": "PRE_ScaleMedInsurance", "unique_values": 7, "type": "rank"},
  "V201380": {"column": "PRE_CorruptionView", "unique_values": 3, "type": "cat"},
  "V201258": {"column": "PRE_ScaleGovAssistanceBlacks", "unique_values": 7, "type": "rank"},
  "V201255": {"column": "PRE_ScaleJobIncome", "unique_values": 7, "type": "rank"},
  "V202051": {"column": "POST_RegistrationStatus", "unique_values": 3, "type": "cat"},
  "V202068x": {"column": "POST_Voted2020", "unique_values": 3, "type": "cat"},
  "V202073": {"column": "POST_VotePresident", "unique_values": 4, "type": "cat"},
  "V202219": {"column": "POST_VoteAccuracy", "unique_values": 5, "type": "rank"},
  "V202156": {"column": "POST_ThermoHarris", "unique_values": 100, "type": "rank"},
  "V202157": {"column": "POST_ThermoPence", "unique_values": 100, "type": "rank"},
  "V202143": {"column": "POST_ThermoBiden", "unique_values": 100, "type": "rank"},
  "V202144": {"column": "POST_ThermoTrump", "unique_values": 100, "type": "rank"},
  "V202123": {"column": "POST_ReasonNotVoting", "unique_values": 15, "type": "cat"},
  "V202205y1": {"column": "POST_ProblemMention", "unique_values": 82, "type": "cat"},
  #"V202580": {"column": "POST_ScaleMedInsurance", "unique_values": 7, "type": "rank"},
  #"V202624": {"column": "POST_HealthSpending", "unique_values": 7, "type": "rank"},
  "V202644": {"column": "POST_RespondentHonesty", "unique_values": 3, "type": "cat"}
}

# %%
column_labels = {
    "V201033": {
        "column": "PRE_VotePresident",
        "labels": {
            1: "Joe Biden",
            2: "Donald Trump",
            3: "Jo Jorgensen",
            4: "Howie Hawkins",
            5: "Other"
        }
    },
    "V201218": {
        "column": "PRE_RaceOutcomePrediction",
        "labels": {
            1: "Will be close",
            2: "Win by quite a bit"
        }
    },
    "V201553": {
        "column": "PRE_ParentNativeStatus",
        "labels": {
            1: "Both parents born in the US",
            2: "One parent born in the US",
            3: "Both parents born in another country"
        }
    },
    "V201600": {
        "column": "Sex",
        "labels": {
            1: "Male",
            2: "Female"
        }
    },
    "V201340": {
        "column": "PRE_AbortionRightsSC",
        "labels": {
            1: "Pleased",
            2: "Upset",
            3: "Neither pleased nor upset"
        }
    },
    "V201510": {
        "column": "EducationLevel",
        "labels": {
            1: "Less than high school credential",
            2: "High school graduate",
            3: "Some college but no degree",
            4: "Associate degree - occupational/vocational",
            5: "Associate degree - academic",
            6: "Bachelor’s degree",
            7: "Master’s degree",
            8: "Professional/Doctoral degree",
        }
    },
    "V201517": {
        "column": "WorkStatus",
        "labels": {
            1: "Yes",
            2: "No, did not work (or retired)"
        }
    },
    "V201549x": {
        "column": "Race",
        "labels": {
            1: "White, non-Hispanic",
            2: "Black, non-Hispanic",
            3: "Hispanic",
            4: "Asian/Pacific Islander, non-Hispanic",
            5: "Native American/Alaska Native, non-Hispanic",
            6: "Multiple races, non-Hispanic"
        }
    },
    "V202054x": {
        "column": "StateRegistration",
        "labels": {
            1: "Alabama",
            2: "Alaska",
            4: "Arizona",
            5: "Arkansas",
            6: "California",
            8: "Colorado",
            9: "Connecticut",
            10: "Delaware",
            11: "Washington DC",
            12: "Florida",
            13: "Georgia",
            15: "Hawaii",
            16: "Idaho",
            17: "Illinois",
            18: "Indiana",
            19: "Iowa",
            20: "Kansas",
            21: "Kentucky",
            22: "Louisiana",
            23: "Maine",
            24: "Maryland",
            25: "Massachusetts",
            26: "Michigan",
            27: "Minnesota",
            28: "Mississippi",
            29: "Missouri",
            30: "Montana",
            31: "Nebraska",
            32: "Nevada",
            33: "New Hampshire",
            34: "New Jersey",
            35: "New Mexico",
            36: "New York",
            37: "North Carolina",
            38: "North Dakota",
            39: "Ohio",
            40: "Oklahoma",
            41: "Oregon",
            42: "Pennsylvania",
            44: "Rhode Island",
            45: "South Carolina",
            46: "South Dakota",
            47: "Tennessee",
            48: "Texas",
            49: "Utah",
            50: "Vermont",
            51: "Virginia",
            53: "Washington",
            54: "West Virginia",
            55: "Wisconsin",
            56: "Wyoming"
        }
    },
    "V201646": {
        "column": "PRE_PartyMoreHouseMembers",
        "labels": {
            1: "correct (D)",
            2: "incorrect (R)"
        }
    },
    "V201645": {
        "column": "PRE_FederalSpendingKnowledge",
        "labels": {
            1: "correct (Foreign aid)",
            2: "incorrect (Medicare, National defense, SS)"
        }
    },
    "V201380": {
        "column": "PRE_CorruptionView",
        "labels": {
            1: "Increased",
            2: "Decreased",
            3: "Stayed the same"
        }
    },
    "V202051": {
        "column": "POST_RegistrationStatus",
        "labels": {
            1: "Registered at this address",
            2: "Registered at a different address",
            3: "Not currently registered"
        }
    },
    "V202068x": {
        "column": "POST_Voted2020",
        "labels": {
            0: "Not registered and did not vote",
            1: "Registered and did not vote",
            2: "Voted"
        }
    },
    "V202073": {
        "column": "POST_VotePresident",
        "labels": {
            1: "Joe Biden",
            2: "Donald Trump",
            3: "Jo Jorgensen",
            4: "Howie Hawkins",
            5: "Other candidate {SPECIFY}"
        }
    },
    "V202205y1": {
        "column": "POST_ProblemMention",
        "labels": {
            1: "Defense spending",
            2: "Middle East",
            3: "Iraq",
            4: "War",
            5: "Terrorism",
            6: "Veterans",
            7: "National defense (all other)",
            8: "Foreign aid",
            9: "Foreign Trade",
            10: "Protection of US jobs",
            11: "Serbia /Balkans",
            12: "China",
            13: "International affairs (all other)",
            14: "Energy crisis",
            15: "Energy prices",
            16: "Energy (all other)",
            17: "Environment",
            18: "Natural Resources (all other)",
            19: "Education and training",
            20: "School funding",
            21: "Education (all other)",
            22: "AIDS",
            23: "Medicare",
            24: "Health (all other)",
            25: "Welfare",
            26: "Poverty",
            27: "Employment",
            28: "Housing",
            29: "Social security",
            30: "Income (all other)",
            31: "Crime",
            32: "Race relations",
            33: "Illegal drugs",
            34: "Police problems",
            35: "Guns",
            36: "Corporate Corruption",
            37: "Justice (all other)",
            38: "Budget",
            39: "Size of government",
            40: "Taxes",
            41: "Immigration",
            42: "Campaign finance",
            43: "Political corruption",
            44: "Ethics",
            45: "Government power",
            46: "Budget priorities",
            47: "Partisan politics",
            48: "Politicians",
            49: "Government (all other)",
            50: "The economy",
            51: "Stock market",
            52: "Economic inequality",
            53: "Recession",
            54: "Inflation",
            55: "Economics (all other)",
            56: "Agriculture",
            57: "Science",
            58: "Commerce",
            59: "Transportation",
            60: "Community development",
            61: "Abortion",
            62: "Child care",
            63: "Overpopulation",
            64: "Public morality",
            65: "Domestic violence",
            66: "Family",
            67: "Young people",
            68: "Sexual identity /LGBT+ issues",
            69: "The media",
            75: "Sexism /Gender issues",
            76: "Afghanistan",
            77: "Syria",
            78: "Elections",
            79: "Religion",
            80: "Civility",
            81: "Unity /division",
            82: "Health care"
        }
    }
}

# %%
path = r"..\data\anes_timeseries_2020_csv_20220210.csv"

# %%
import sys
import os
import importlib

# Add the directory containing the file to the Python path
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(path), 'functions')))

# Import the function
from functions import load_data

# Reload the module to reflect any updates
importlib.reload(load_data)

data_filtered = load_data.load_data(path, dictionary)
# Out:
# C:\Users\15184\OneDrive\Documents\Statistical Principals for Data Science\electionAnalysis\dslc_documentation\functions\load_data.py:7: DtypeWarning: Columns (15,17,18,19,21,22,23,25,26,27,29,30,31,33,34,35,37,38,1508,1509) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)  # Modify this if your data is in a different format (e.g., .xlsx, .json, etc.)

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8280 entries, 0 to 8279
# Data columns (total 62 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PRE_VotePresident                8280 non-null   int64
#  1   PRE_RaceOutcomePrediction        8280 non-null   int64
#  2   PRE_ThermoBiden                  8280 non-null   int64
#  3   PRE_ThermoTrump                  8280 non-null   int64
#  4   PRE_ThermoHarris                 8280 non-null   int64
#  5   PRE_ThermoPence                  8280 non-null   int64
#  6   PRE_ThermoObama                  8280 non-null   int64
#  7   PRE_ThermoDemParty               8280 non-null   int64
#  8   PRE_ThermoRepParty               8280 non-null   int64
#  9   PRE_ParentNativeStatus           8280 non-null   int64
#  10  PRE_YearsAtAddress               8280 non-null   int64
#  11  Sex                              8280 non-null   int64
#  12  PRE_SummaryVoteDutyChoice        8280 non-null   int64
#  13  PRE_PartyID                      8280 non-null   int64
#  14  PRE_ScaleSpendingServices        8280 non-null   int64
#  15  PRE_CountryDirection             8280 non-null   int64
#  16  PRE_GovTrust                     8280 non-null   int64
#  17  PRE_EconomyView                  8280 non-null   int64
#  18  PRE_AbortionRightsSC             8280 non-null   int64
#  19  Age                              8280 non-null   int64
#  20  EducationLevel                   8280 non-null   int64
#  21  WorkStatus                       8280 non-null   int64
#  22  Income                           8280 non-null   int64
#  23  Race                             8280 non-null   int64
#  24  StateRegistration                8280 non-null   int64
#  25  HouseholdChildren                8280 non-null   int64
#  26  PRE_Fox_Hannity                  8280 non-null   int64
#  27  PRE_Fox_TuckerCarlsonTonight     8280 non-null   int64
#  28  PRE_Fox_SpecialReportBretBaier   8280 non-null   int64
#  29  PRE_Fox_TheFive                  8280 non-null   int64
#  30  PRE_Fox_TheIngrahamAngle         8280 non-null   int64
#  31  PRE_Fox_TheStoryMarthaMacCallum  8280 non-null   int64
#  32  PRE_Fox_FoxAndFriends            8280 non-null   int64
#  33  PRE_Fox_FoxNewsWebsite           8280 non-null   int64
#  34  PRE_CNN_TheLeadJakeTapper        8280 non-null   int64
#  35  PRE_CNN_AndersonCooper360        8280 non-null   int64
#  36  PRE_CNN_CuomoPrimeTime           8280 non-null   int64
#  37  PRE_CNN_ErinBurnettOutFront      8280 non-null   int64
#  38  PRE_CNN_CNNWebsite               8280 non-null   int64
#  39  PRE_ABC_WorldNewsTonight         8280 non-null   int64
#  40  PRE_ABC_2020                     8280 non-null   int64
#  41  PRE_ABC_GoodMorningAmerica       8280 non-null   int64
#  42  PRE_PartyMoreHouseMembers        8280 non-null   int64
#  43  PRE_FederalSpendingKnowledge     8280 non-null   int64
#  44  PRE_VoteAccuracy                 8280 non-null   int64
#  45  PRE_SurveySeriousness            8280 non-null   int64
#  46  PRE_ScaleDefenseSpending         8280 non-null   int64
#  47  PRE_ScaleMedInsurance            8280 non-null   int64
#  48  PRE_CorruptionView               8280 non-null   int64
#  49  PRE_ScaleGovAssistanceBlacks     8280 non-null   int64
#  50  PRE_ScaleJobIncome               8280 non-null   int64
#  51  POST_RegistrationStatus          8280 non-null   int64
#  52  POST_Voted2020                   8280 non-null   int64
#  53  POST_VotePresident               8280 non-null   int64
#  54  POST_VoteAccuracy                8280 non-null   int64
#  55  POST_ThermoHarris                8280 non-null   int64
#  56  POST_ThermoPence                 8280 non-null   int64
#  57  POST_ThermoBiden                 8280 non-null   int64
#  58  POST_ThermoTrump                 8280 non-null   int64
#  59  POST_ReasonNotVoting             8280 non-null   int64
#  60  POST_ProblemMention              8280 non-null   int64
#  61  POST_RespondentHonesty           8280 non-null   int64
# dtypes: int64(62)
# memory usage: 3.9 MB

# %%
data_filtered_num = data_filtered.select_dtypes(include='number')

# Compute the correlation matrix
correlation_matrix = data_filtered_num.corr()

# Extract the upper triangle of the correlation matrix (to avoid duplicates)
upper_triangle = correlation_matrix.where(
    ~correlation_matrix.apply(lambda x: x.index.to_series() >= x.name)
)

# Unstack the matrix into a Series and sort by values
sorted_correlations = upper_triangle.unstack().dropna().sort_values()

# Get the top negative and positive correlations
top_negative = sorted_correlations.head(15)  # Adjust the number to see more
top_positive = sorted_correlations.tail(15)  # Adjust the number to see more

# Display results
print("Top Negative Correlations:\n", top_negative)
print("\nTop Positive Correlations:\n", top_positive)
# Out:
# Top Negative Correlations:
#  PRE_ThermoTrump     PRE_ThermoObama      -0.744000
#                     PRE_ThermoBiden      -0.692895
# PRE_ThermoObama     POST_ThermoTrump     -0.680679
# PRE_ThermoTrump     POST_ThermoBiden     -0.659753
#                     PRE_ThermoDemParty   -0.642706
# PRE_ThermoBiden     POST_ThermoTrump     -0.633113
# PRE_ThermoDemParty  POST_ThermoTrump     -0.585299
# PRE_ThermoRepParty  PRE_ThermoObama      -0.570714
# PRE_ThermoTrump     POST_ThermoHarris    -0.552223
# PRE_ThermoRepParty  PRE_ThermoBiden      -0.540317
#                     POST_ThermoBiden     -0.519356
# POST_ThermoTrump    POST_ThermoBiden     -0.513552
# PRE_ThermoObama     POST_ThermoPence     -0.494797
# PRE_ThermoTrump     PRE_EconomyView      -0.469436
# PRE_ThermoBiden     POST_ThermoPence     -0.458362
# dtype: float64
#
# Top Positive Correlations:
#  POST_VotePresident       POST_ScaleMedInsurance     0.791339
# POST_VoteStatus          POST_VoteAccuracy          0.795725
# PRE_ThermoObama          PRE_ThermoBiden            0.797460
# POST_VoteAccuracy        POST_RespondentHonesty     0.823541
# POST_ScaleMedInsurance   POST_RegistrationStatus    0.827768
# POST_RegistrationStatus  POST_HealthSpending        0.827768
# POST_VoteStatus          POST_RespondentHonesty     0.829274
# POST_VoteAccuracy        POST_ScaleMedInsurance     0.864733
#                          POST_HealthSpending        0.864733
# POST_VoteStatus          POST_ScaleMedInsurance     0.873775
#                          POST_HealthSpending        0.873775
#                          POST_VotePresident         0.877704
# POST_ScaleMedInsurance   POST_RespondentHonesty     0.959366
# POST_RespondentHonesty   POST_HealthSpending        0.959366
# POST_ScaleMedInsurance   POST_HealthSpending        1.000000
# dtype: float64

# %%
from scipy.stats import ttest_rel, wilcoxon
# Separate PRE and POST columns
pre_columns = [col for col in data_filtered_num.columns if col.startswith("PRE_")]
post_columns = [col for col in data_filtered_num.columns if col.startswith("POST_")]

# Match PRE and POST columns (ignoring "PRE_" and "POST_" prefixes)
pre_post_pairs = {
    pre: pre.replace("PRE_", "POST_") for pre in pre_columns if pre.replace("PRE_", "POST_") in post_columns
}

# Prepare a DataFrame to store test results
results = []

# Compare each PRE-POST pair
for pre_col, post_col in pre_post_pairs.items():
    pre_data = data_filtered_num[pre_col].dropna()
    post_data = data_filtered_num[post_col].dropna()
    
    # Ensure equal length for paired testing
    paired_data = pd.DataFrame({"pre": pre_data, "post": post_data}).dropna()
    pre_values = paired_data["pre"]
    post_values = paired_data["post"]
    
    # Perform paired t-test (use Wilcoxon if data is non-normal)
    try:
        t_stat, p_value = ttest_rel(pre_values, post_values)
        test_type = "t-test"
    except ValueError:
        t_stat, p_value = wilcoxon(pre_values, post_values)
        test_type = "Wilcoxon"
    
    # Store results
    results.append({
        "Variable": pre_col.replace("PRE_", ""),
        "PRE_Mean": pre_values.mean(),
        "POST_Mean": post_values.mean(),
        "Test_Type": test_type,
        "T_Statistic": t_stat,
        "P_Value": p_value
    })

# Convert results to a DataFrame
comparison_results = pd.DataFrame(results)

# Display significant changes (p-value < 0.05)
significant_changes = comparison_results[comparison_results["P_Value"] < 0.05]

print("Significant Changes from Pre to Post:")
print(significant_changes)
# Out:
# Significant Changes from Pre to Post:
#             Variable   PRE_Mean  POST_Mean Test_Type  T_Statistic  \
# 0      VotePresident  -0.894807   0.238889    t-test   -38.021702
# 1        ThermoBiden  47.812319  46.919807    t-test     2.646178
# 2        ThermoTrump  39.055314  33.297705    t-test    19.603202
# 3       ThermoHarris  49.675362  46.183816    t-test     5.108380
# 4        ThermoPence  44.637077  40.408454    t-test     7.077247
# 5       VoteAccuracy   3.004469   1.355193    t-test    45.964388
# 6  ScaleMedInsurance  14.064855  -1.560870    t-test    47.659814
#
#          P_Value
# 0  1.051193e-291
# 1   8.156082e-03
# 2   1.123396e-83
# 3   3.321833e-07
# 4   1.590451e-12
# 5   0.000000e+00
# 6   0.000000e+00

# %% [markdown]
# That's a lot of data!

# %% [markdown]
# ## Step 3: Examine the data
#
# In this section we explore the common messy data traits to identify any cleaning action items.

# %% [markdown]
# ### Finding invalid values

# %%
data_filtered.describe()
# Out:
#        PRE_VotePresident  PRE_RaceOutcomePrediction  PRE_ThermoBiden  \
# count        8280.000000                8280.000000      8280.000000
# mean           -0.894807                   1.253261        47.812319
# std             0.623393                   0.992782        36.806871
# min            -9.000000                  -9.000000        -9.000000
# 25%            -1.000000                   1.000000        15.000000
# 50%            -1.000000                   1.000000        50.000000
# 75%            -1.000000                   2.000000        85.000000
# max            12.000000                   2.000000       998.000000
#
#        PRE_ThermoTrump  PRE_ThermoHarris  PRE_ThermoPence  PRE_ThermoObama  \
# count      8280.000000       8280.000000      8280.000000      8280.000000
# mean         39.055314         49.675362        44.637077        59.907488
# std          40.571078         65.887540        55.784589        37.425584
# min          -9.000000         -9.000000        -9.000000        -9.000000
# 25%           0.000000          0.000000         0.000000        30.000000
# 50%          30.000000         50.000000        50.000000        70.000000
# 75%          85.000000         85.000000        75.000000       100.000000
# max         100.000000        999.000000       999.000000       100.000000
#
#        PRE_ThermoDemParty  PRE_ThermoRepParty  PRE_ParentNativeStatus  \
# count         8280.000000         8280.000000             8280.000000
# mean            44.752536           43.131763                1.231643
# std             35.949072           36.148125                0.969502
# min             -9.000000           -9.000000               -9.000000
# 25%             15.000000           15.000000                1.000000
# 50%             50.000000           40.000000                1.000000
# 75%             70.000000           70.000000                1.000000
# max            998.000000          998.000000                3.000000
#
#        PRE_YearsAtAddress          Sex  PRE_SummaryVoteDutyChoice  \
# count         8280.000000  8280.000000                8280.000000
# mean            11.610507     1.456522                   3.251449
# std             12.098934     1.066932                   2.406670
# min             -9.000000    -9.000000                  -2.000000
# 25%              2.000000     1.000000                   1.000000
# 50%              7.000000     2.000000                   2.000000
# 75%             19.000000     2.000000                   6.000000
# max             40.000000     2.000000                   7.000000
#
#        PRE_PartyID  PRE_ScaleSpendingServices  PRE_PartyRegistration  \
# count  8280.000000                8280.000000            8280.000000
# mean      3.833816                  18.079106               0.568478
# std       2.397490                  33.187170               1.795337
# min      -9.000000                  -9.000000              -9.000000
# 25%       2.000000                   4.000000              -1.000000
# 50%       4.000000                   5.000000               1.000000
# 75%       6.000000                   7.000000               2.000000
# max       7.000000                  99.000000               5.000000
#
#        PRE_CountryDirection  PRE_GovTrust  PRE_EconomyView  \
# count           8280.000000   8280.000000      8280.000000
# mean               1.675483      3.420531         3.212802
# std                0.941906      1.207423         1.261308
# min               -9.000000     -9.000000        -9.000000
# 25%                1.000000      3.000000         2.000000
# 50%                2.000000      4.000000         3.000000
# 75%                2.000000      4.000000         4.000000
# max                2.000000      5.000000         5.000000
#
#        PRE_AbortionRightsSC          Age  EducationLevel   WorkStatus  \
# count           8280.000000  8280.000000     8280.000000  8280.000000
# mean               1.977899    49.038889        5.532126     0.298188
# std                1.233611    20.771267        9.987560     1.480671
# min               -9.000000    -9.000000       -9.000000    -9.000000
# 25%                2.000000    35.000000        3.000000    -1.000000
# 50%                2.000000    51.000000        5.000000    -1.000000
# 75%                3.000000    65.000000        6.000000     2.000000
# max                3.000000    80.000000       95.000000     2.000000
#
#             Income         Race  StateRegistration  HouseholdChildren  \
# count  8280.000000  8280.000000        8280.000000        8280.000000
# mean     10.221739     1.498913          23.251691           0.533213
# std       8.444621     1.698425          18.594514           1.313558
# min      -9.000000    -9.000000          -9.000000          -9.000000
# 25%       4.000000     1.000000           6.000000           0.000000
# 50%      11.000000     1.000000          24.000000           0.000000
# 75%      17.000000     2.000000          39.000000           1.000000
# max      22.000000     6.000000          56.000000           4.000000
#
#        PRE_Fox_Hannity  PRE_Fox_TuckerCarlsonTonight  \
# count      8280.000000                   8280.000000
# mean         -0.253623                     -0.250242
# std           0.951118                      0.953788
# min          -9.000000                     -9.000000
# 25%           0.000000                      0.000000
# 50%           0.000000                      0.000000
# 75%           0.000000                      0.000000
# max           1.000000                      1.000000
#
#        PRE_Fox_SpecialReportBretBaier  PRE_Fox_TheFive  \
# count                     8280.000000      8280.000000
# mean                        -0.267633        -0.259300
# std                          0.939846         0.946592
# min                         -9.000000        -9.000000
# 25%                          0.000000         0.000000
# 50%                          0.000000         0.000000
# 75%                          0.000000         0.000000
# max                          1.000000         1.000000
#
#        PRE_Fox_TheIngrahamAngle  PRE_Fox_TheStoryMarthaMacCallum  \
# count               8280.000000                      8280.000000
# mean                  -0.268961                        -0.275362
# std                    0.938759                         0.933479
# min                   -9.000000                        -9.000000
# 25%                    0.000000                         0.000000
# 50%                    0.000000                         0.000000
# 75%                    0.000000                         0.000000
# max                    1.000000                         1.000000
#
#        PRE_Fox_FoxAndFriends  PRE_Fox_FoxNewsWebsite  \
# count            8280.000000             8280.000000
# mean               -0.229469               -0.306039
# std                 0.969770                1.008629
# min                -9.000000               -9.000000
# 25%                 0.000000               -1.000000
# 50%                 0.000000                0.000000
# 75%                 0.000000                0.000000
# max                 1.000000                1.000000
#
#        PRE_CNN_TheLeadJakeTapper  PRE_CNN_AndersonCooper360  \
# count                8280.000000                8280.000000
# mean                   -0.268116                  -0.238164
# std                     0.939451                   0.963166
# min                    -9.000000                  -9.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                     1.000000                   1.000000
#
#        PRE_CNN_CuomoPrimeTime  PRE_CNN_ErinBurnettOutFront  \
# count             8280.000000                  8280.000000
# mean                -0.256763                    -0.278382
# std                  0.948621                     0.930962
# min                 -9.000000                    -9.000000
# 25%                  0.000000                     0.000000
# 50%                  0.000000                     0.000000
# 75%                  0.000000                     0.000000
# max                  1.000000                     1.000000
#
#        PRE_CNN_CNNWebsite  PRE_ABC_WorldNewsTonight  PRE_ABC_2020  \
# count         8280.000000               8280.000000   8280.000000
# mean            -0.257126                 -0.212319     -0.236473
# std              1.045849                  0.982437      0.964460
# min             -9.000000                 -9.000000     -9.000000
# 25%             -1.000000                  0.000000      0.000000
# 50%              0.000000                  0.000000      0.000000
# 75%              0.000000                  0.000000      0.000000
# max              1.000000                  1.000000      1.000000
#
#        PRE_ABC_GoodMorningAmerica  PRE_PartyMoreHouseMembers  \
# count                 8280.000000                8280.000000
# mean                    -0.224758                   1.086957
# std                      0.973295                   1.468080
# min                     -9.000000                  -9.000000
# 25%                      0.000000                   1.000000
# 50%                      0.000000                   1.000000
# 75%                      0.000000                   2.000000
# max                      1.000000                   2.000000
#
#        PRE_FederalSpendingKnowledge  PRE_VoteAccuracy  PRE_SurveySeriousness  \
# count                   8280.000000       8280.000000            8280.000000
# mean                       2.032850          3.004469               4.558092
# std                        2.098351          1.485154               1.447893
# min                       -9.000000         -9.000000              -9.000000
# 25%                        1.000000          2.000000               5.000000
# 50%                        2.000000          3.000000               5.000000
# 75%                        4.000000          4.000000               5.000000
# max                        4.000000          5.000000               5.000000
#
#        PRE_ScaleDefenseSpending  PRE_ScaleMedInsurance  PRE_CorruptionView  \
# count               8280.000000            8280.000000         8280.000000
# mean                  16.971256              14.064855            1.620169
# std                   32.377374              29.738682            1.348386
# min                   -9.000000              -9.000000           -9.000000
# 25%                    3.000000               2.000000            1.000000
# 50%                    5.000000               4.000000            1.000000
# 75%                    6.000000               7.000000            3.000000
# max                   99.000000              99.000000            3.000000
#
#        PRE_ScaleGovAssistanceBlacks  PRE_ScaleJobIncome  \
# count                   8280.000000         8280.000000
# mean                      13.264734           14.743841
# std                       28.716329           30.002713
# min                       -9.000000           -9.000000
# 25%                        2.000000            3.000000
# 50%                        4.000000            4.000000
# 75%                        6.000000            7.000000
# max                       99.000000           99.000000
#
#        POST_RegistrationStatus  POST_VoteStatus  POST_VotePresident  \
# count              8280.000000      8280.000000         8280.000000
# mean                 -1.511111         2.453382            0.238889
# std                   1.533102         3.144927            2.566320
# min                  -7.000000        -9.000000           -9.000000
# 25%                  -1.000000         3.000000           -1.000000
# 50%                  -1.000000         4.000000            1.000000
# 75%                  -1.000000         4.000000            2.000000
# max                  -1.000000         4.000000           12.000000
#
#        POST_VoteAccuracy  POST_ThermoHarris  POST_ThermoPence  \
# count        8280.000000        8280.000000       8280.000000
# mean            1.355193          46.183816         40.408454
# std             2.825230          48.731938         47.695825
# min            -9.000000          -9.000000         -9.000000
# 25%             1.000000           0.000000          0.000000
# 50%             2.000000          50.000000         30.000000
# 75%             3.000000          85.000000         75.000000
# max             5.000000         999.000000        999.000000
#
#        POST_ThermoBiden  POST_ThermoTrump  POST_ReasonNotVoting  \
# count       8280.000000       8280.000000           8280.000000
# mean          46.919807         33.297705             -0.520652
# std           38.600682         40.314633              3.970426
# min           -9.000000         -9.000000             -9.000000
# 25%            0.000000          0.000000             -1.000000
# 50%           50.000000         10.000000             -1.000000
# 75%           85.000000         70.000000             -1.000000
# max          100.000000        100.000000             16.000000
#
#        POST_ProblemMention  POST_ScaleMedInsurance  POST_HealthSpending  \
# count               8280.0             8280.000000          8280.000000
# mean                  -2.0               -1.560870            -1.560870
# std                    0.0                1.579909             1.579909
# min                   -2.0               -7.000000            -7.000000
# 25%                   -2.0               -1.000000            -1.000000
# 50%                   -2.0               -1.000000            -1.000000
# 75%                   -2.0               -1.000000            -1.000000
# max                   -2.0               -1.000000            -1.000000
#
#        POST_RespondentHonesty
# count             8280.000000
# mean                -1.459058
# std                  1.684504
# min                 -7.000000
# 25%                 -1.000000
# 50%                 -1.000000
# 75%                 -1.000000
# max                  3.000000

# %% [markdown]
# #### Numeric variables

# %%
from functions import prepare_data

importlib.reload(prepare_data)

ranked_columns, num_columns, cat_columns = prepare_data.extract_ranked_num_and_cat_columns(dictionary)

print(ranked_columns)
print(num_columns)
# Out:
# ['PRE_ThermoBiden', 'PRE_ThermoTrump', 'PRE_ThermoHarris', 'PRE_ThermoPence', 'PRE_ThermoObama', 'PRE_ThermoDemParty', 'PRE_ThermoRepParty', 'PRE_SummaryVoteDutyChoice', 'PRE_PartyID', 'PRE_ScaleSpendingServices', 'PRE_CountryDirection', 'PRE_GovTrust', 'PRE_EconomyView', 'Income', 'HouseholdChildren', 'PRE_VoteAccuracy', 'PRE_SurveySeriousness', 'PRE_ScaleDefenseSpending', 'PRE_ScaleMedInsurance', 'PRE_ScaleGovAssistanceBlacks', 'PRE_ScaleJobIncome', 'POST_VoteAccuracy', 'POST_ThermoHarris', 'POST_ThermoPence', 'POST_ThermoBiden', 'POST_ThermoTrump']
# ['PRE_YearsAtAddress', 'Age']

# %% [markdown]
# #### Categorical variables

# %%
print(cat_columns)
# Out:
# ['PRE_VotePresident', 'PRE_RaceOutcomePrediction', 'PRE_ParentNativeStatus', 'Sex', 'PRE_AbortionRightsSC', 'EducationLevel', 'WorkStatus', 'Race', 'StateRegistration', 'PRE_Fox_Hannity', 'PRE_Fox_TuckerCarlsonTonight', 'PRE_Fox_SpecialReportBretBaier', 'PRE_Fox_TheFive', 'PRE_Fox_TheIngrahamAngle', 'PRE_Fox_TheStoryMarthaMacCallum', 'PRE_Fox_FoxAndFriends', 'PRE_Fox_FoxNewsWebsite', 'PRE_CNN_TheLeadJakeTapper', 'PRE_CNN_AndersonCooper360', 'PRE_CNN_CuomoPrimeTime', 'PRE_CNN_ErinBurnettOutFront', 'PRE_CNN_CNNWebsite', 'PRE_ABC_WorldNewsTonight', 'PRE_ABC_2020', 'PRE_ABC_GoodMorningAmerica', 'PRE_PartyMoreHouseMembers', 'PRE_FederalSpendingKnowledge', 'PRE_CorruptionView', 'POST_RegistrationStatus', 'POST_Voted2020', 'POST_VotePresident', 'POST_ReasonNotVoting', 'POST_ProblemMention', 'POST_RespondentHonesty']

# %% [markdown]
# ### Examining missing values

# %%
# Count missing values for each column
missing_values_count = data_filtered.isna().sum()

# Display the counts
print("Missing values count for each column:")
print(missing_values_count)

# Filter out columns with no missing values
missing_values_greater_than_zero = missing_values_count[missing_values_count > 0]

print()
# Display the counts for columns with missing values
print("Missing values count for columns with missing values greater than 0:")
print(missing_values_greater_than_zero)
# Out:
# Missing values count for each column:
# PRE_VotePresident            0
# PRE_RaceOutcomePrediction    0
# PRE_ThermoBiden              0
# PRE_ThermoTrump              0
# PRE_ThermoHarris             0
#                             ..
# POST_ReasonNotVoting         0
# POST_ProblemMention          0
# POST_ScaleMedInsurance       0
# POST_HealthSpending          0
# POST_RespondentHonesty       0
# Length: 65, dtype: int64
#
# Missing values count for columns with missing values greater than 0:
# Series([], dtype: int64)

# %% [markdown]
# ### Examining the data format

# %% [markdown]
# ### Assessing column names

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8280 entries, 0 to 8279
# Data columns (total 63 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PRE_VotePresident                8280 non-null   int64
#  1   PRE_RaceOutcomePrediction        8280 non-null   int64
#  2   PRE_ThermoBiden                  8280 non-null   int64
#  3   PRE_ThermoTrump                  8280 non-null   int64
#  4   PRE_ThermoHarris                 8280 non-null   int64
#  5   PRE_ThermoPence                  8280 non-null   int64
#  6   PRE_ThermoObama                  8280 non-null   int64
#  7   PRE_ThermoDemParty               8280 non-null   int64
#  8   PRE_ThermoRepParty               8280 non-null   int64
#  9   PRE_ParentNativeStatus           8280 non-null   int64
#  10  PRE_YearsAtAddress               8280 non-null   int64
#  11  Sex                              8280 non-null   int64
#  12  PRE_SummaryVoteDutyChoice        8280 non-null   int64
#  13  PRE_PartyID                      8280 non-null   int64
#  14  PRE_ScaleSpendingServices        8280 non-null   int64
#  15  PRE_PartyRegistration            8280 non-null   int64
#  16  PRE_CountryDirection             8280 non-null   int64
#  17  PRE_GovTrust                     8280 non-null   int64
#  18  PRE_EconomyView                  8280 non-null   int64
#  19  PRE_AbortionRightsSC             8280 non-null   int64
#  20  Age                              8280 non-null   int64
#  21  EducationLevel                   8280 non-null   int64
#  22  WorkStatus                       8280 non-null   int64
#  23  Income                           8280 non-null   int64
#  24  Race                             8280 non-null   int64
#  25  StateRegistration                8280 non-null   int64
#  26  HouseholdChildren                8280 non-null   int64
#  27  PRE_Fox_Hannity                  8280 non-null   int64
#  28  PRE_Fox_TuckerCarlsonTonight     8280 non-null   int64
#  29  PRE_Fox_SpecialReportBretBaier   8280 non-null   int64
#  30  PRE_Fox_TheFive                  8280 non-null   int64
#  31  PRE_Fox_TheIngrahamAngle         8280 non-null   int64
#  32  PRE_Fox_TheStoryMarthaMacCallum  8280 non-null   int64
#  33  PRE_Fox_FoxAndFriends            8280 non-null   int64
#  34  PRE_Fox_FoxNewsWebsite           8280 non-null   int64
#  35  PRE_CNN_TheLeadJakeTapper        8280 non-null   int64
#  36  PRE_CNN_AndersonCooper360        8280 non-null   int64
#  37  PRE_CNN_CuomoPrimeTime           8280 non-null   int64
#  38  PRE_CNN_ErinBurnettOutFront      8280 non-null   int64
#  39  PRE_CNN_CNNWebsite               8280 non-null   int64
#  40  PRE_ABC_WorldNewsTonight         8280 non-null   int64
#  41  PRE_ABC_2020                     8280 non-null   int64
#  42  PRE_ABC_GoodMorningAmerica       8280 non-null   int64
#  43  PRE_PartyMoreHouseMembers        8280 non-null   int64
#  44  PRE_FederalSpendingKnowledge     8280 non-null   int64
#  45  PRE_VoteAccuracy                 8280 non-null   int64
#  46  PRE_SurveySeriousness            8280 non-null   int64
#  47  PRE_ScaleDefenseSpending         8280 non-null   int64
#  48  PRE_ScaleMedInsurance            8280 non-null   int64
#  49  PRE_CorruptionView               8280 non-null   int64
#  50  PRE_ScaleGovAssistanceBlacks     8280 non-null   int64
#  51  PRE_ScaleJobIncome               8280 non-null   int64
#  52  POST_RegistrationStatus          8280 non-null   int64
#  53  POST_VoteStatus                  8280 non-null   int64
#  54  POST_VotePresident               8280 non-null   int64
#  55  POST_VoteAccuracy                8280 non-null   int64
#  56  POST_ThermoHarris                8280 non-null   int64
#  57  POST_ThermoPence                 8280 non-null   int64
#  58  POST_ThermoBiden                 8280 non-null   int64
#  59  POST_ThermoTrump                 8280 non-null   int64
#  60  POST_ReasonNotVoting             8280 non-null   int64
#  61  POST_ProblemMention              8280 non-null   int64
#  62  POST_RespondentHonesty           8280 non-null   int64
# dtypes: int64(63)
# memory usage: 4.0 MB

# %% [markdown]
# ### Assessing variable type

# %% [markdown]
# ### Evaluating data completeness

# %% [markdown]
# ### Answering any unanswered questions

# %% [markdown]
# ## Step 4: Prepare the data
#
# Don't forget to split the data into training, validation and test sets before you clean and pre-process it!

# %%
from functions import prepare_data

importlib.reload(prepare_data)

data_processed = prepare_data.clean_columns(data_filtered, dictionary)

# %%
data_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8280 entries, 0 to 8279
# Data columns (total 62 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PRE_VotePresident                7049 non-null   float64
#  1   PRE_RaceOutcomePrediction        8213 non-null   float64
#  2   PRE_ThermoBiden                  8060 non-null   float64
#  3   PRE_ThermoTrump                  8048 non-null   float64
#  4   PRE_ThermoHarris                 7980 non-null   float64
#  5   PRE_ThermoPence                  8045 non-null   float64
#  6   PRE_ThermoObama                  8165 non-null   float64
#  7   PRE_ThermoDemParty               8152 non-null   float64
#  8   PRE_ThermoRepParty               8141 non-null   float64
#  9   PRE_ParentNativeStatus           8239 non-null   float64
#  10  PRE_YearsAtAddress               8119 non-null   float64
#  11  Sex                              8213 non-null   float64
#  12  PRE_SummaryVoteDutyChoice        8259 non-null   float64
#  13  PRE_PartyID                      8245 non-null   float64
#  14  PRE_ScaleSpendingServices        7067 non-null   float64
#  15  PRE_CountryDirection             8257 non-null   float64
#  16  PRE_GovTrust                     8243 non-null   float64
#  17  PRE_EconomyView                  8259 non-null   float64
#  18  PRE_AbortionRightsSC             8209 non-null   float64
#  19  Age                              7932 non-null   float64
#  20  EducationLevel                   8149 non-null   float64
#  21  WorkStatus                       8247 non-null   float64
#  22  Income                           7664 non-null   float64
#  23  Race                             8178 non-null   float64
#  24  StateRegistration                7051 non-null   float64
#  25  HouseholdChildren                8219 non-null   float64
#  26  PRE_Fox_Hannity                  6421 non-null   float64
#  27  PRE_Fox_TuckerCarlsonTonight     6421 non-null   float64
#  28  PRE_Fox_SpecialReportBretBaier   6421 non-null   float64
#  29  PRE_Fox_TheFive                  6421 non-null   float64
#  30  PRE_Fox_TheIngrahamAngle         6421 non-null   float64
#  31  PRE_Fox_TheStoryMarthaMacCallum  6421 non-null   float64
#  32  PRE_Fox_FoxAndFriends            6421 non-null   float64
#  33  PRE_Fox_FoxNewsWebsite           5290 non-null   float64
#  34  PRE_CNN_TheLeadJakeTapper        6421 non-null   float64
#  35  PRE_CNN_AndersonCooper360        6421 non-null   float64
#  36  PRE_CNN_CuomoPrimeTime           6421 non-null   float64
#  37  PRE_CNN_ErinBurnettOutFront      6421 non-null   float64
#  38  PRE_CNN_CNNWebsite               5290 non-null   float64
#  39  PRE_ABC_WorldNewsTonight         6421 non-null   float64
#  40  PRE_ABC_2020                     6421 non-null   float64
#  41  PRE_ABC_GoodMorningAmerica       6421 non-null   float64
#  42  PRE_PartyMoreHouseMembers        8057 non-null   float64
#  43  PRE_FederalSpendingKnowledge     8028 non-null   float64
#  44  PRE_VoteAccuracy                 8224 non-null   float64
#  45  PRE_SurveySeriousness            8148 non-null   float64
#  46  PRE_ScaleDefenseSpending         7138 non-null   float64
#  47  PRE_ScaleMedInsurance            7352 non-null   float64
#  48  PRE_CorruptionView               8202 non-null   float64
#  49  PRE_ScaleGovAssistanceBlacks     7403 non-null   float64
#  50  PRE_ScaleJobIncome               7322 non-null   float64
#  51  POST_RegistrationStatus          625 non-null    float64
#  52  POST_Voted2020                   7441 non-null   float64
#  53  POST_VotePresident               5821 non-null   float64
#  54  POST_VoteAccuracy                7397 non-null   float64
#  55  POST_ThermoHarris                7347 non-null   float64
#  56  POST_ThermoPence                 7362 non-null   float64
#  57  POST_ThermoBiden                 7375 non-null   float64
#  58  POST_ThermoTrump                 7359 non-null   float64
#  59  POST_ReasonNotVoting             779 non-null    float64
#  60  POST_ProblemMention              6903 non-null   float64
#  61  POST_RespondentHonesty           384 non-null    float64
# dtypes: float64(62)
# memory usage: 3.9 MB

# %%
# Calculate the threshold for allowed missing values (70% valid data)
threshold = len(data_processed) * 0.5

# Get the initial columns
original_columns = set(data_processed.columns)

# Drop columns with more than 50% missing values
data_dropped = data_processed.dropna(axis=1, thresh=threshold)

# Get the dropped columns
dropped_columns = original_columns - set(data_dropped.columns)

print("\nDropped columns:")
print(dropped_columns)
# Out:
# Dropped columns:
# {'POST_ReasonNotVoting', 'POST_RespondentHonesty', 'POST_RegistrationStatus'}

# %%
# Safely remove keys from the dictionary
for col in list(dictionary.keys()):  # Iterate over a list of keys to avoid modifying during iteration
    if dictionary[col]['column'] in dropped_columns:
        print(dictionary[col]['column'])
        del dictionary[col]

# %%
importlib.reload(prepare_data)

# Test for optimal k
data_imputed = prepare_data.knn_impute(data_dropped, dictionary)

# %%
data_imputed['POST_ProblemMention'].value_counts()
# Out:
# POST_ProblemMention
# 82    2155
# 32     672
# 81     608
# 47     402
# 49     363
#       ...
# 15       1
# 23       1
# 1        1
# 22       1
# 76       1
# Name: count, Length: 76, dtype: int64

# %%
importlib.reload(prepare_data)
data_imputed = prepare_data.group_top_and_other(data_imputed,'POST_ProblemMention')

# %%
print(data_imputed['POST_ProblemMention'].value_counts())
# Out:
# POST_ProblemMention
# 83    2996
# 82    2155
# 32     672
# 81     608
# 47     402
# 49     363
# 50     347
# 48     311
# 24     238
# 78     188
# Name: count, dtype: int64

# %%
importlib.reload(prepare_data)
data_imputed = prepare_data.replace_all_other_cols(data_imputed, 'PRE_FederalSpendingKnowledge', 1)

# %%
data_imputed['PRE_FederalSpendingKnowledge'].value_counts()
# Out:
# PRE_FederalSpendingKnowledge
# 0    5228
# 1    3052
# Name: count, dtype: int64

# %%
importlib.reload(prepare_data)
data_combined = prepare_data.combine_columns_by_group(data_imputed)

# %%
data_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8280 entries, 0 to 8279
# Data columns (total 46 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PRE_VotePresident             8280 non-null   int32
#  1   PRE_RaceOutcomePrediction     8280 non-null   int32
#  2   PRE_ThermoBiden               8280 non-null   int32
#  3   PRE_ThermoTrump               8280 non-null   int32
#  4   PRE_ThermoHarris              8280 non-null   int32
#  5   PRE_ThermoPence               8280 non-null   int32
#  6   PRE_ThermoObama               8280 non-null   int32
#  7   PRE_ThermoDemParty            8280 non-null   int32
#  8   PRE_ThermoRepParty            8280 non-null   int32
#  9   PRE_ParentNativeStatus        8280 non-null   int32
#  10  PRE_YearsAtAddress            8280 non-null   float64
#  11  Sex                           8280 non-null   int32
#  12  PRE_SummaryVoteDutyChoice     8280 non-null   int32
#  13  PRE_PartyID                   8280 non-null   int32
#  14  PRE_ScaleSpendingServices     8280 non-null   int32
#  15  PRE_CountryDirection          8280 non-null   int32
#  16  PRE_GovTrust                  8280 non-null   int32
#  17  PRE_EconomyView               8280 non-null   int32
#  18  PRE_AbortionRightsSC          8280 non-null   int32
#  19  Age                           8280 non-null   float64
#  20  EducationLevel                8280 non-null   int32
#  21  WorkStatus                    8280 non-null   int32
#  22  Income                        8280 non-null   int32
#  23  Race                          8280 non-null   int32
#  24  StateRegistration             8280 non-null   int32
#  25  HouseholdChildren             8280 non-null   int32
#  26  PRE_PartyMoreHouseMembers     8280 non-null   int32
#  27  PRE_FederalSpendingKnowledge  8280 non-null   int32
#  28  PRE_VoteAccuracy              8280 non-null   int32
#  29  PRE_SurveySeriousness         8280 non-null   int32
#  30  PRE_ScaleDefenseSpending      8280 non-null   int32
#  31  PRE_ScaleMedInsurance         8280 non-null   int32
#  32  PRE_CorruptionView            8280 non-null   int32
#  33  PRE_ScaleGovAssistanceBlacks  8280 non-null   int32
#  34  PRE_ScaleJobIncome            8280 non-null   int32
#  35  POST_Voted2020                8280 non-null   int32
#  36  POST_VotePresident            8280 non-null   int32
#  37  POST_VoteAccuracy             8280 non-null   int32
#  38  POST_ThermoHarris             8280 non-null   int32
#  39  POST_ThermoPence              8280 non-null   int32
#  40  POST_ThermoBiden              8280 non-null   int32
#  41  POST_ThermoTrump              8280 non-null   int32
#  42  POST_ProblemMention           8280 non-null   int64
#  43  mentionFox                    8280 non-null   int32
#  44  mentionABC                    8280 non-null   int32
#  45  mentionCNN                    8280 non-null   int32
# dtypes: float64(2), int32(43), int64(1)
# memory usage: 1.5 MB

# %%
data_combined['POST_ProblemMention'].value_counts()
# Out:
# POST_ProblemMention
# 83    2815
# 82    2155
# 32     672
# 81     608
# 47     402
# 49     363
# 50     347
# 48     311
# 24     238
# 78     188
# 17     181
# Name: count, dtype: int64

# %%
importlib.reload(prepare_data)
data_one_hot = prepare_data.one_hot_cat_cols(data_combined, dictionary,column_labels)

# %%
data_one_hot
# Out:
#       PRE_ThermoBiden  PRE_ThermoTrump  PRE_ThermoHarris  PRE_ThermoPence  \
# 0                   0              100                 0               85
# 1                   0                0                 0                0
# 2                  65                0                65                0
# 3                  70               15                85               15
# 4                  15               85                15               90
# ...               ...              ...               ...              ...
# 8275                0              100                 0               50
# 8276               50               70                50               70
# 8277               70               30                85               15
# 8278                0              100                 0              100
# 8279               60                0                50               15
#
#       PRE_ThermoObama  PRE_ThermoDemParty  PRE_ThermoRepParty  \
# 0                   0                   0                  85
# 1                  50                   0                  50
# 2                  90                  60                   0
# 3                  85                  50                  70
# 4                  10                  20                  70
# ...               ...                 ...                 ...
# 8275                0                   0                 100
# 8276               50                  40                  70
# 8277               70                  85                  50
# 8278                0                   0                  70
# 8279               70                  60                  30
#
#       PRE_YearsAtAddress  PRE_SummaryVoteDutyChoice  PRE_PartyID  \
# 0                   10.0                          1            7
# 1                    4.0                          4            4
# 2                   11.0                          4            3
# 3                   20.0                          1            6
# 4                   10.0                          1            4
# ...                  ...                        ...          ...
# 8275                 1.0                          1            7
# 8276                22.0                          5            6
# 8277                 6.0                          1            1
# 8278                16.0                          1            7
# 8279                 0.0                          5            1
#
#       PRE_ScaleSpendingServices  PRE_CountryDirection  PRE_GovTrust  \
# 0                             1                     3             5
# 1                             3                     1             5
# 2                             6                     1             4
# 3                             7                     2             3
# 4                             2                     4             5
# ...                         ...                   ...           ...
# 8275                          7                     3             2
# 8276                          4                     2             4
# 8277                          5                     3             4
# 8278                          2                     3             4
# 8279                          6                     1             3
#
#       PRE_EconomyView   Age  Income  HouseholdChildren  PRE_VoteAccuracy  \
# 0                   2  46.0      21                  0                 3
# 1                   3  37.0      13                  1                 2
# 2                   4  40.0      17                  2                 3
# 3                   4  41.0       7                  1                 4
# 4                   4  72.0      22                  0                 2
# ...               ...   ...     ...                ...               ...
# 8275                2  26.0       8                  2                 4
# 8276                4  52.0      19                  0                 3
# 8277                2  45.0      16                  0                 4
# 8278                2  65.0      14                  0                 1
# 8279                4  38.0      15                  1                 5
#
#       PRE_SurveySeriousness  PRE_ScaleDefenseSpending  PRE_ScaleMedInsurance  \
# 0                         5                         7                      7
# 1                         5                         4                      4
# 2                         5                         1                      2
# 3                         5                         4                      1
# 4                         5                         4                      5
# ...                     ...                       ...                    ...
# 8275                      5                         6                      1
# 8276                      5                         5                      5
# 8277                      5                         7                      4
# 8278                      5                         6                      6
# 8279                      5                         4                      1
#
#       PRE_ScaleGovAssistanceBlacks  PRE_ScaleJobIncome  POST_VoteAccuracy  \
# 0                                7                   7                  2
# 1                                4                   5                  2
# 2                                3                   4                  1
# 3                                3                   7                  1
# 4                                6                   7                  3
# ...                            ...                 ...                ...
# 8275                             5                   2                  4
# 8276                             5                   4                  1
# 8277                             4                   4                  1
# 8278                             7                   7                  5
# 8279                             1                   2                  1
#
#       POST_ThermoHarris  POST_ThermoPence  POST_ThermoBiden  POST_ThermoTrump  \
# 0                     0                85                 0               100
# 1                     0                 0                15                15
# 2                    80                 0                85                 0
# 3                    85                50               100                60
# 4                     0                95                 0                90
# ...                 ...               ...               ...               ...
# 8275                 22                50                40               100
# 8276                 40                70                40                70
# 8277                 70                20                60                30
# 8278                  0               100                 0               100
# 8279                 85                15                70                 0
#
#       mentionFox  mentionABC  mentionCNN  PRE_VotePresident_Joe Biden  \
# 0              0           0           0                        False
# 1              0           0           0                        False
# 2              0           0           1                         True
# 3              0           0           0                         True
# 4              1           0           0                        False
# ...          ...         ...         ...                          ...
# 8275           0           0           0                        False
# 8276           0           0           0                        False
# 8277           0           0           0                         True
# 8278           0           0           0                        False
# 8279           0           0           1                         True
#
#       PRE_VotePresident_Donald Trump  PRE_VotePresident_Jo Jorgensen  \
# 0                               True                           False
# 1                              False                            True
# 2                              False                           False
# 3                              False                           False
# 4                               True                           False
# ...                              ...                             ...
# 8275                            True                           False
# 8276                            True                           False
# 8277                           False                           False
# 8278                            True                           False
# 8279                           False                           False
#
#       PRE_VotePresident_Howie Hawkins  PRE_VotePresident_Other  \
# 0                               False                    False
# 1                               False                    False
# 2                               False                    False
# 3                               False                    False
# 4                               False                    False
# ...                               ...                      ...
# 8275                            False                    False
# 8276                            False                    False
# 8277                            False                    False
# 8278                            False                    False
# 8279                            False                    False
#
#       PRE_RaceOutcomePrediction_Will be close  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                        True
# ...                                       ...
# 8275                                    False
# 8276                                     True
# 8277                                     True
# 8278                                    False
# 8279                                     True
#
#       PRE_RaceOutcomePrediction_Win by quite a bit  \
# 0                                             True
# 1                                            False
# 2                                             True
# 3                                             True
# 4                                            False
# ...                                            ...
# 8275                                          True
# 8276                                         False
# 8277                                         False
# 8278                                          True
# 8279                                         False
#
#       PRE_ParentNativeStatus_Both parents born in the US  \
# 0                                                 False
# 1                                                  True
# 2                                                  True
# 3                                                 False
# 4                                                  True
# ...                                                 ...
# 8275                                              False
# 8276                                              False
# 8277                                              False
# 8278                                               True
# 8279                                              False
#
#       PRE_ParentNativeStatus_One parent born in the US  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 8275                                             False
# 8276                                             False
# 8277                                             False
# 8278                                             False
# 8279                                             False
#
#       PRE_ParentNativeStatus_Both parents born in another country  Sex_Male  \
# 0                                                 False                True
# 1                                                 False               False
# 2                                                 False               False
# 3                                                  True                True
# 4                                                 False                True
# ...                                                 ...                 ...
# 8275                                               True               False
# 8276                                               True               False
# 8277                                               True                True
# 8278                                              False               False
# 8279                                               True               False
#
#       Sex_Female  PRE_AbortionRightsSC_Pleased  PRE_AbortionRightsSC_Upset  \
# 0          False                          True                       False
# 1           True                         False                        True
# 2           True                         False                        True
# 3          False                         False                       False
# 4          False                          True                       False
# ...          ...                           ...                         ...
# 8275        True                         False                        True
# 8276        True                          True                       False
# 8277       False                         False                        True
# 8278        True                          True                       False
# 8279        True                         False                        True
#
#       PRE_AbortionRightsSC_Neither pleased nor upset  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
# ...                                              ...
# 8275                                           False
# 8276                                           False
# 8277                                           False
# 8278                                           False
# 8279                                           False
#
#       EducationLevel_Less than high school credential  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 8275                                            False
# 8276                                            False
# 8277                                            False
# 8278                                            False
# 8279                                            False
#
#       EducationLevel_High school graduate  \
# 0                                   False
# 1                                   False
# 2                                    True
# 3                                   False
# 4                                   False
# ...                                   ...
# 8275                                False
# 8276                                False
# 8277                                 True
# 8278                                False
# 8279                                False
#
#       EducationLevel_Some college but no degree  \
# 0                                         False
# 1                                          True
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 8275                                      False
# 8276                                      False
# 8277                                      False
# 8278                                      False
# 8279                                      False
#
#       EducationLevel_Associate degree - occupational/vocational  ...  \
# 0                                                 False          ...
# 1                                                 False          ...
# 2                                                 False          ...
# 3                                                  True          ...
# 4                                                 False          ...
# ...                                                 ...          ...
# 8275                                               True          ...
# 8276                                              False          ...
# 8277                                              False          ...
# 8278                                              False          ...
# 8279                                              False          ...
#
#       StateRegistration_New Hampshire  StateRegistration_New Jersey  \
# 0                               False                         False
# 1                               False                         False
# 2                               False                         False
# 3                               False                         False
# 4                               False                         False
# ...                               ...                           ...
# 8275                            False                         False
# 8276                            False                         False
# 8277                            False                         False
# 8278                            False                         False
# 8279                            False                         False
#
#       StateRegistration_New Mexico  StateRegistration_New York  \
# 0                            False                       False
# 1                            False                       False
# 2                            False                       False
# 3                            False                       False
# 4                            False                       False
# ...                            ...                         ...
# 8275                         False                       False
# 8276                         False                       False
# 8277                         False                       False
# 8278                         False                       False
# 8279                         False                       False
#
#       StateRegistration_North Carolina  StateRegistration_North Dakota  \
# 0                                False                           False
# 1                                False                           False
# 2                                False                           False
# 3                                False                           False
# 4                                False                           False
# ...                                ...                             ...
# 8275                             False                           False
# 8276                             False                           False
# 8277                             False                           False
# 8278                             False                           False
# 8279                             False                           False
#
#       StateRegistration_Ohio  StateRegistration_Oklahoma  \
# 0                      False                        True
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
# ...                      ...                         ...
# 8275                   False                       False
# 8276                   False                       False
# 8277                   False                       False
# 8278                   False                       False
# 8279                   False                       False
#
#       StateRegistration_Oregon  StateRegistration_Pennsylvania  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 8275                     False                           False
# 8276                     False                           False
# 8277                     False                           False
# 8278                     False                           False
# 8279                     False                           False
#
#       StateRegistration_43  StateRegistration_Rhode Island  \
# 0                    False                           False
# 1                    False                           False
# 2                    False                           False
# 3                    False                           False
# 4                    False                           False
# ...                    ...                             ...
# 8275                 False                           False
# 8276                 False                           False
# 8277                 False                           False
# 8278                 False                           False
# 8279                 False                           False
#
#       StateRegistration_South Carolina  StateRegistration_South Dakota  \
# 0                                False                           False
# 1                                False                           False
# 2                                False                           False
# 3                                False                           False
# 4                                False                           False
# ...                                ...                             ...
# 8275                             False                           False
# 8276                             False                           False
# 8277                             False                           False
# 8278                             False                           False
# 8279                             False                           False
#
#       StateRegistration_Tennessee  StateRegistration_Texas  \
# 0                           False                    False
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                           False                    False
# ...                           ...                      ...
# 8275                        False                    False
# 8276                        False                    False
# 8277                        False                    False
# 8278                        False                    False
# 8279                        False                    False
#
#       StateRegistration_Utah  StateRegistration_Vermont  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
# ...                      ...                        ...
# 8275                   False                      False
# 8276                   False                      False
# 8277                   False                      False
# 8278                   False                      False
# 8279                   False                      False
#
#       StateRegistration_Virginia  StateRegistration_Washington  \
# 0                          False                         False
# 1                          False                         False
# 2                           True                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 8275                       False                         False
# 8276                       False                         False
# 8277                       False                         False
# 8278                        True                         False
# 8279                        True                         False
#
#       StateRegistration_West Virginia  StateRegistration_Wisconsin  \
# 0                               False                        False
# 1                               False                        False
# 2                               False                        False
# 3                               False                        False
# 4                               False                        False
# ...                               ...                          ...
# 8275                            False                        False
# 8276                            False                        False
# 8277                            False                        False
# 8278                            False                        False
# 8279                            False                        False
#
#       StateRegistration_Wyoming  PRE_PartyMoreHouseMembers_correct (D)  \
# 0                         False                                   True
# 1                         False                                  False
# 2                         False                                   True
# 3                         False                                  False
# 4                         False                                   True
# ...                         ...                                    ...
# 8275                      False                                  False
# 8276                      False                                  False
# 8277                      False                                  False
# 8278                      False                                   True
# 8279                      False                                  False
#
#       PRE_PartyMoreHouseMembers_incorrect (R)  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                        True
# 4                                       False
# ...                                       ...
# 8275                                     True
# 8276                                     True
# 8277                                     True
# 8278                                    False
# 8279                                     True
#
#       PRE_FederalSpendingKnowledge_correct (Foreign aid)  \
# 0                                                 False
# 1                                                 False
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 8275                                              False
# 8276                                              False
# 8277                                              False
# 8278                                              False
# 8279                                              False
#
#       PRE_FederalSpendingKnowledge_incorrect (Medicare, National defense, SS)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 8275                                               True
# 8276                                              False
# 8277                                              False
# 8278                                              False
# 8279                                               True
#
#       PRE_FederalSpendingKnowledge_3  PRE_FederalSpendingKnowledge_4  \
# 0                               True                           False
# 1                              False                            True
# 2                              False                           False
# 3                              False                           False
# 4                              False                           False
# ...                              ...                             ...
# 8275                           False                           False
# 8276                           False                            True
# 8277                           False                            True
# 8278                           False                            True
# 8279                           False                           False
#
#       PRE_CorruptionView_Increased  PRE_CorruptionView_Decreased  \
# 0                            False                          True
# 1                            False                         False
# 2                             True                         False
# 3                             True                         False
# 4                             True                         False
# ...                            ...                           ...
# 8275                          True                         False
# 8276                         False                         False
# 8277                          True                         False
# 8278                         False                          True
# 8279                          True                         False
#
#       PRE_CorruptionView_Stayed the same  \
# 0                                  False
# 1                                   True
# 2                                  False
# 3                                  False
# 4                                  False
# ...                                  ...
# 8275                               False
# 8276                                True
# 8277                               False
# 8278                               False
# 8279                               False
#
#       POST_Voted2020_Not registered and did not vote  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 8275                                           False
# 8276                                           False
# 8277                                           False
# 8278                                           False
# 8279                                           False
#
#       POST_Voted2020_Registered and did not vote  POST_Voted2020_Voted  \
# 0                                           True                 False
# 1                                          False                  True
# 2                                          False                  True
# 3                                          False                  True
# 4                                          False                  True
# ...                                          ...                   ...
# 8275                                        True                 False
# 8276                                       False                  True
# 8277                                       False                  True
# 8278                                       False                  True
# 8279                                       False                  True
#
#       POST_VotePresident_Joe Biden  POST_VotePresident_Donald Trump  \
# 0                            False                             True
# 1                            False                            False
# 2                             True                            False
# 3                             True                            False
# 4                            False                             True
# ...                            ...                              ...
# 8275                         False                             True
# 8276                         False                             True
# 8277                          True                            False
# 8278                         False                             True
# 8279                          True                            False
#
#       POST_VotePresident_Jo Jorgensen  POST_VotePresident_Howie Hawkins  \
# 0                               False                             False
# 1                                True                             False
# 2                               False                             False
# 3                               False                             False
# 4                               False                             False
# ...                               ...                               ...
# 8275                            False                             False
# 8276                            False                             False
# 8277                            False                             False
# 8278                            False                             False
# 8279                            False                             False
#
#       POST_ProblemMention_Environment  POST_ProblemMention_Health (all other)  \
# 0                               False                                   False
# 1                               False                                   False
# 2                               False                                   False
# 3                               False                                   False
# 4                               False                                   False
# ...                               ...                                     ...
# 8275                            False                                   False
# 8276                            False                                   False
# 8277                            False                                    True
# 8278                            False                                   False
# 8279                            False                                   False
#
#       POST_ProblemMention_Race relations  \
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ...                                  ...
# 8275                               False
# 8276                               False
# 8277                               False
# 8278                               False
# 8279                               False
#
#       POST_ProblemMention_Partisan politics  POST_ProblemMention_Politicians  \
# 0                                     False                            False
# 1                                     False                            False
# 2                                      True                            False
# 3                                     False                            False
# 4                                     False                            False
# ...                                     ...                              ...
# 8275                                  False                            False
# 8276                                  False                            False
# 8277                                  False                            False
# 8278                                  False                            False
# 8279                                  False                            False
#
#       POST_ProblemMention_Government (all other)  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 8275                                       False
# 8276                                       False
# 8277                                       False
# 8278                                       False
# 8279                                       False
#
#       POST_ProblemMention_The economy  POST_ProblemMention_Elections  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
# ...                               ...                            ...
# 8275                            False                          False
# 8276                            False                          False
# 8277                            False                          False
# 8278                            False                          False
# 8279                            False                          False
#
#       POST_ProblemMention_Unity /division  POST_ProblemMention_Health care  \
# 0                                   False                            False
# 1                                    True                            False
# 2                                   False                            False
# 3                                   False                             True
# 4                                   False                            False
# ...                                   ...                              ...
# 8275                                 True                            False
# 8276                                 True                            False
# 8277                                False                            False
# 8278                                False                            False
# 8279                                False                             True
#
#       POST_ProblemMention_83
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                       True
# ...                      ...
# 8275                   False
# 8276                   False
# 8277                   False
# 8278                    True
# 8279                   False
#
# [8280 rows x 143 columns]

# %%
train_data, val_data, test_data = prepare_data.split_data(data_imputed)

# %%
# Save the datasets to CSV files
train_data.to_csv('train_data.csv', index=False)
val_data.to_csv('val_data.csv', index=False)
test_data.to_csv('test_data.csv', index=False)
